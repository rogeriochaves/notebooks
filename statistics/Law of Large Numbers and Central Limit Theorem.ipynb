# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Normal

# %%
dist = np.random.normal(size=10000)
print("std", np.std(dist))
plt.hist(dist, bins=100);
# Out:
# std 0.9915032932794109

# %%
def plot_std_reduction(distribution):
    m = 500
    stds = []
    for n in range(1, m):
        dist = np.mean(distribution(n), axis=1)
        stds.append(np.std(dist))

    print("std", np.std(dist))
    plt.title("std * n=100")
    plt.hist(dist, bins=100)
    plt.show()

    plt.xlabel = "n"
    plt.ylabel = "std"
    plt.yticks(np.array(range(0, 11)) / 10)
    plt.ylim(0, 1)
    plt.plot(list(range(1, m)), stds);
    
plot_std_reduction(lambda n: np.random.normal(size=(10000, n)))
# Out:
# std 0.044625539406539676

# %% [markdown]
# # Beta

# %%
dist = np.random.beta(0.5, 0.5, size=10000)
print("std", np.std(dist))
plt.hist(dist, bins=100);
# Out:
# std 0.35343753273877976

# %%
plot_std_reduction(lambda n: np.random.beta(0.5, 0.5, size=(10000, n)))
# Out:
# std 0.03541329793242702

# %% [markdown]
# # Exponential

# %%
dist = np.random.exponential(2, size=10000)
print("std", np.std(dist))
plt.hist(dist, bins=100);
# Out:
# std 1.9753510356671098

# %%
plot_std_reduction(lambda n: np.random.exponential(2, size=(10000, n)))
# Out:
# std 0.08915987090857068

# %% [markdown]
# # Power Law

# %%
dist = np.random.pareto(2, size=10000)
print("std", np.std(dist))
plt.hist(dist, bins=100);
# Out:
# std 2.6272141592807556

# %%
plot_std_reduction(lambda n: np.random.pareto(2, size=(10000, n)))
# Out:
# std 0.17380178908477426
