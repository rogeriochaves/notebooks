# %%
import subprocess

command = "pip3 install pandas numpy causality"
print(subprocess.check_output(['bash','-c',command]).decode('utf-8'))
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/site-packages (0.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (1.13.1)
# Requirement already satisfied: causality in /usr/local/lib/python3.6/site-packages (0.0.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/site-packages (from pandas) (2017.3)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/site-packages (from pandas) (2.7.3)
# Requirement already satisfied: pymc in /usr/local/lib/python3.6/site-packages (from causality) (2.3.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/site-packages (from causality) (4.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from causality) (1.11.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/site-packages (from causality) (0.19.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.6/site-packages (from causality) (0.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/site-packages (from causality) (1.11)
# Requirement already satisfied: patsy in /usr/local/lib/python3.6/site-packages (from causality) (0.5.0)

# %%
import numpy as np
import pandas as pd
from causality.analysis.dataframe import CausalDataFrame
# %matplotlib inline

# %% [markdown]
# Let's confound $X$ and $Y$ with a couple of $Z$ variables, $z_1$ and $z_2$

# %%
N = 1000
lower = -1
upper = 1
z1 = np.random.uniform(lower, upper, size=N)
z2 = np.random.uniform(lower, upper, size=N)
x  = np.random.uniform(lower, upper, size=N) + (z1 + z2)/2.
z  = z1 + z2
y  = np.random.normal(size=N) - x + 2.* z
X  = CausalDataFrame({'x': x, 'y': y, 'z1': z1, 'z2': z2})

# %% [markdown]
# The causal effect of $X$ on $Y$ is given by cutting the edge from $Z_1$ and $Z_2$ into $X$. Taking the expectation of the $Y$ formula, using that $Z$ and $X$ are now independent, we see the conditional expecation is now $y(x) = E[Y|X=x] = E[U - X + 2Z|X=x] = 0 - E[X|X=x] + 2 E[Z|X=x] = - x + 2 E[Z] = - x$, where $U \sim \mathcal{N}(0,1)$. The naive plot looks nothing like $y = -x$:

# %%
X.plot(x='x', y='y', style='bo', alpha=0.2, kind='scatter');

# %% [markdown]
# but let's check the plot after back-door adjustment for $Z_1$ and $Z_2$ ...

# %%
X.zplot(x='x', y='y', z=['z1', 'z2'], z_types={'z1': 'c', 'z2': 'c'}, kind='line', model_type='kernel')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-8f3dfdad7951> in <module>()
# ----> 1 X.zplot(x='x', y='y', z=['z1', 'z2'], z_types={'z1': 'c', 'z2': 'c'}, kind='line', model_type='kernel')
#
# /usr/local/lib/python3.6/site-packages/causality/analysis/dataframe.py in zplot(self, *args, **kwargs)
#      53         if kwargs.get('z', []):
#      54             if kwargs.get('kind') == 'line':
# ---> 55                 return self._line_zplot(*args, **kwargs)
#      56             if kwargs.get('kind') == 'bar' or kwargs.get('kind') == 'mean':
#      57                 return self._bootstrapped_mean_zplot(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/causality/analysis/dataframe.py in _line_zplot(self, *args, **kwargs)
#      64
#      65     def _line_zplot(self, *args, **kwargs):
# ---> 66         model, arg_key = self._get_model(*args, **kwargs)
#      67         if arg_key:
#      68             del kwargs[arg_key]
#
# /usr/local/lib/python3.6/site-packages/causality/analysis/dataframe.py in _get_model(self, *args, **kwargs)
#     123             model = KernelModelWrapper()
#     124             arg_key = 'model_type'
# --> 125             model.fit(self[[treatment] + confounders], self[outcome], variable_types=variable_types)
#     126         else:
#     127             model = RandomForestRegressor()
#
# /usr/local/lib/python3.6/site-packages/causality/analysis/dataframe.py in fit(self, X, y, variable_types)
#     142         if variable_types:
#     143             variable_type_string = ''.join([variable_types[col] for col in X.columns])
# --> 144             self.model = KernelReg(y, X, variable_type_string, reg_type='ll')
#     145         else:
#     146             self.model = KernelReg(y, X, 'c' * X.shape[1], reg_type='ll')
#
# /usr/local/lib/python3.6/site-packages/statsmodels/nonparametric/kernel_regression.py in __init__(self, endog, exog, var_type, reg_type, bw, defaults)
#     100         self._set_defaults(defaults)
#     101         if not self.efficient:
# --> 102             self.bw = self._compute_reg_bw(bw)
#     103         else:
#     104             self.bw = self._compute_efficient(bw)
#
# /usr/local/lib/python3.6/site-packages/statsmodels/nonparametric/kernel_regression.py in _compute_reg_bw(self, bw)
#     118             func = self.est[self.reg_type]
#     119             bw_estimated = optimize.fmin(res, x0=h0, args=(func, ),
# --> 120                                          maxiter=1e3, maxfun=1e3, disp=0)
#     121             return bw_estimated
#     122
#
# /usr/local/lib/python3.6/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     391             'initial_simplex': initial_simplex}
#     392
# --> 393     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     394     if full_output:
#     395         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /usr/local/lib/python3.6/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, **unknown_options)
#     536         if fxr < fsim[0]:
#     537             xe = (1 + rho * chi) * xbar - rho * chi * sim[-1]
# --> 538             fxe = func(xe)
#     539
#     540             if fxe < fxr:
#
# /usr/local/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /usr/local/lib/python3.6/site-packages/statsmodels/nonparametric/kernel_regression.py in cv_loo(self, bw, func)
#     308             Y = next(LOO_Y)
#     309             G = func(bw, endog=Y, exog=-X_not_i,
# --> 310                      data_predict=-self.exog[ii, :])[0]
#     311             L += (self.endog[ii] - G) ** 2
#     312
#
# /usr/local/lib/python3.6/site-packages/statsmodels/nonparametric/kernel_regression.py in _est_loc_linear(self, bw, endog, exog, data_predict)
#     176         V[1:, 0] = ((exog - data_predict) * ker_endog).sum(axis=0)
#     177
# --> 178         mean_mfx = np.dot(np.linalg.pinv(M), V)
#     179         mean = mean_mfx[0]
#     180         mfx = mean_mfx[1:, :]
#
# /usr/local/lib/python3.6/site-packages/numpy/linalg/linalg.py in pinv(a, rcond)
#    1645         return wrap(res)
#    1646     a = a.conjugate()
# -> 1647     u, s, vt = svd(a, 0)
#    1648     m = u.shape[0]
#    1649     n = vt.shape[1]
#
# /usr/local/lib/python3.6/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1387
#    1388         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1389         u, s, vt = gufunc(a, signature=signature, extobj=extobj)
#    1390         u = u.astype(result_t, copy=False)
#    1391         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
N = 1000

z = np.random.normal(1., size=N)
x = np.random.binomial(1, p=1./(1. + np.exp(z/.1)))
y = x + z + np.random.normal(size=N)

df = CausalDataFrame({'x': x, 'y': y, 'z': z})

df.zplot(x='x', y='y', z=['z'], kind='mean', bootstrap_samples=1000)
